# %% [markdown]
# # stage 01 이후 피험자 Fz 체크

# %%
import polars as pl 

df = pl.read_csv("output\\01_dataset\\cop_qc\\fz_qc_summary.csv")
df1 = df.group_by("subject")\
    .agg(pl.col("fz_corrected_median_n").mean())
    
print(df1)
# Out:
# shape: (52, 2)
# ┌─────────┬───────────────────────┐
# │ subject ┆ fz_corrected_median_n │
# │ ---     ┆ ---                   │
# │ str     ┆ f64                   │
# ╞═════════╪═══════════════════════╡
# │ 강비은  ┆ 572.109321            │
# │ 이명희  ┆ 430.795254            │
# │ 방수진  ┆ 645.213246            │
# │ 송석란  ┆ 718.636295            │
# │ 조민석  ┆ 696.670707            │
# │ …       ┆ …                     │
# │ 가윤호  ┆ 687.104419            │
# │ 이인섭  ┆ 631.749137            │
# │ 이은수  ┆ 700.139339            │
# │ 최지유  ┆ 645.313768            │
# │ 노선자  ┆ 491.44438             │
# └─────────┴───────────────────────┘
